# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # **STEP 1 : CREATE A NODE CLASS**

# %% [markdown]
# **This helps in creating trees**

# %%
class Node: 
    def __init__(self, predicted_class):
        self.left = None
        self.right = None
        self.threshold = 0
        self.feature_index =  0
        self.predicted_class = predicted_class

# %% [markdown]
# # __STEP 2 : CREATE A GINI IMPURITY METHOD__

# %%
def gini(self , y):
    classes , counts = np.unique(y, return_counts = True)
    impurity  = 1 - np.sum([(count/len(y)) **2 for count in counts])
    return impurity

# %% [markdown]
# # **STEP 3 : FIND THE BEST SPLIT**

# %% [markdown]
# **#testing my code to see what's happening underneath the hood**

# %%
#testing my code to see what's happening underneath the hood

def gini_impurity(y, n_classes, m):
    num_parent = [sum(y == c) for c in range(n_classes)]
    print(num_parent)
    gini = sum((n/m) ** 2 for n in num_parent)
    print(gini)


y = np.array([0, 0, 1, 1, 2, 2, 3, 4,5])
n_classes = 6
m = len(y)

gini_impurity(y, n_classes, m)
# Out:
# [2, 2, 2, 1, 1, 1]
# 0.18518518518518517

# %%
def best_split(X, y, n_classes , n_features):
    #we need the base case 
    m = len(y)
    if m <= 1 : #made the fist correction here  (it is m<=1)
        return None , None
    #we need to get the best current gini 

    num_parent =  [np.sum(y==c) for c in range(n_classes)]     #had some doubt here about the code #(was right , np.sum)
    best_gini = 1 - sum([(n/m)**2 for n in num_parent])
    best_feature , best_threshold = None , None 

    

    #now lets go find the best feature and threshold in our dataset
    for feature in range(n_features):
        feature_values = X[:, features]
        thresholds, classes = zip(*sorted(zip(feature_values ,y)))     #made another blunder here again too

        #initilize left and right split to eventually help in splitting
        num_left = [0] * n_classes
        num_right = num_parent.copy()

        for i in range(1, m):
            c = classes[i-1]
            num_left[c] += 1
            num_right[c] -= 1


            gini_right =  1 - sum([(num_left[c]/i)**2 for c in range(n_classes)])
            gini_left =  1 - sum([(num_left[c]/(m-i))**2 for c in range(n_classes)])

            #weighted_gini 
            gini =  ((gini_right*i) + (gini_left*(m-i)))/ m    # i think i still have issues getting this side 


           #checked if splitting threshold are the same 
           
           
           if thresholds[i-1] == thresholds[i]:
            continue 


           if gini < best_gini :
            best_gini = gini 
            best_threshold = (thresholds[i-1] + threshold[i]) /2
            best_feature = feature 
    return best_threshold , best_feature
